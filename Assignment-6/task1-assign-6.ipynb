# %%
class Student:
    def __init__(self, name, roll_number, age, grade):
        """
        Initializes the Student object with name, roll number, age, and grade.
        """
        self.name = name
        self.roll_number = roll_number
        self.age = age
        self.grade = grade

    def display_details(self):
        """
        Prints the student's details in a readable format.
        """
        print("Student Details:")
        print(f"  Name: {self.name}")
        print(f"  Roll Number: {self.roll_number}")
        print(f"  Age: {self.age}")
        print(f"  Grade: {self.grade}")

# Example usage:
student1 = Student("Priya", 101, 20, "A")
student1.display_details()
# Out:
# Student Details:
#   Name: Priya
#   Roll Number: 101
#   Age: 20
#   Grade: A
