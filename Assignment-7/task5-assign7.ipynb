# %%
numbers = [1, 2, 3]
index = 5

if 0 <= index < len(numbers):
    print(numbers[index])
else:
    print(f"Error: Index {index} is out of range. List length is {len(numbers)}.")
# Out:
# Error: Index 5 is out of range. List length is 3.
